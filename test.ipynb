# %%
import pandas as pd

# %%
df = pd.read_csv("NBAPlayer_Preference_data_clean.csv")

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#         rk               player pos  age   tm   g  gs    mp   fg   fga    fg%  \
# 0        1   Mahmoud Abdul-Rauf  PG   28  SAC  31   0  17.1  3.3   8.8  0.377
# 1        2    Tariq Abdul-Wahad  SG   23  SAC  59  16  16.3  2.4   6.1  0.403
# 2        3  Shareef Abdur-Rahim  SF   21  VAN  82  82  36.0  8.0  16.4  0.485
# 3        4       Cory Alexander  PG   24  TOT  60  22  21.6  2.9   6.7  0.428
# 4        4       Cory Alexander  PG   24  SAS  37   3  13.5  1.6   3.9  0.414
# ...    ...                  ...  ..  ...  ...  ..  ..   ...  ...   ...    ...
# 14568  601       Thaddeus Young  PF   33  TOR  26   0  18.3  2.6   5.5  0.465
# 14569  602           Trae Young  PG   23  ATL  76  76  34.9  9.4  20.3  0.460
# 14570  603       Omer Yurtseven   C   23  MIA  56  12  12.6  2.3   4.4  0.526
# 14571  604          Cody Zeller   C   29  POR  27   0  13.1  1.9   3.3  0.567
# 14572  605          Ivica Zubac   C   24  LAC  76  76  24.4  4.1   6.5  0.626
#
# ...
